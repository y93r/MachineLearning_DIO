# %% [markdown]
# <a href="https://colab.research.google.com/github/y93r/MachineLearning_DIO/blob/main/Ex_HSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/bolinha_tenis.jpg')
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
blur = cv2.medianBlur(hsv ,11)

lower = np.array([33,137,50])
upper = np.array([50,245,245])

mask = cv2.inRange(blur, lower, upper)
res = cv2.bitwise_and(image,image, mask= mask)            

cv2_imshow(mask)

cv2_imshow(np.hstack([image, res]))
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=799x428 at 0x7EFD881BA890>
# <PIL.Image.Image image mode=RGB size=1598x428 at 0x7EFD881BAAD0>
# -1
